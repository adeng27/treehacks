# %%
import pandas as pd

# Read the contents of the file
file_path = "xd.txt"
phone_numbers = []
messages = []

# Iterate over each line in the file
with open(file_path, "r", encoding="utf-8", errors="ignore") as file:
    for line in file:
        try:
            line = line.strip().encode('utf-8').decode('utf-8')
        except UnicodeDecodeError:
            continue

        # Check if the line contains the catchphrase
        if line.strip() == "+17737937551":
            # Get the content from the next line
            next_line = next(file, '').strip()
            messages.append(next_line)
            phone_numbers.append("+17737937551")

# Create a pandas DataFrame
df = pd.DataFrame({'Phone Number': phone_numbers, 'Message': messages})
print(df)
# Out:
#       Phone Number                                            Message
# 0     +17737937551          Sorry I missed your call. Need something?
# 1     +17737937551                                             Hello?
# 2     +17737937551               Yes, please ask if can move to 11:30
# 3     +17737937551                                          Thank you
# 4     +17737937551                                 Why what happened?
# ...            ...                                                ...
# 4667  +17737937551                                How about the case?
# 4668  +17737937551  Send me the link and I can order using my cc a...
# 4669  +17737937551  Btw, did you get to talk to your physics teach...
# 4670  +17737937551  Btw, makena went to the gym yesterday and got ...
# 4671  +17737937551  There is nothing wrong carrying a small bag or...
#
# [4672 rows x 2 columns]

# %%
import pandas as pd
import re

# Read the contents of the file
file_path = "xd.txt"
phone_numbers = []
messages = []

# Regex pattern to match date (assuming date format is YYYY-MM-DD)
date_pattern = re.compile(r'\d{4}-\d{2}-\d{2}')

# Iterate over each line in the file
with open(file_path, "r", encoding="utf-8", errors="ignore") as file:
    for line in file:
        try:
            line = line.strip().encode('utf-8').decode('utf-8')
        except UnicodeDecodeError:
            continue

        # Check if the line contains a date
        if date_pattern.search(line):
            break  # Stop reading lines if a date is found

        # Check if the line contains the catchphrase
        if line.strip() == "+17737937551":
            # Get the content from the next line
            next_line = next(file, '').strip()
            messages.append(next_line)
            phone_numbers.append("+17737937551")

# Create a pandas DataFrame
df = pd.DataFrame({'Phone Number': phone_numbers, 'Message': messages})
print(df)
# Out:
#       Phone Number                                            Message
# 0     +17737937551          Sorry I missed your call. Need something?
# 1     +17737937551                                             Hello?
# 2     +17737937551               Yes, please ask if can move to 11:30
# 3     +17737937551                                          Thank you
# 4     +17737937551                                 Why what happened?
# ...            ...                                                ...
# 4667  +17737937551                                How about the case?
# 4668  +17737937551  Send me the link and I can order using my cc a...
# 4669  +17737937551  Btw, did you get to talk to your physics teach...
# 4670  +17737937551  Btw, makena went to the gym yesterday and got ...
# 4671  +17737937551  There is nothing wrong carrying a small bag or...
#
# [4672 rows x 2 columns]

# %%
import pandas as pd
import re

# Read the contents of the file
file_path = "xd.txt"
phone_numbers = []
messages = []

# Regex pattern to match date (assuming date format is YYYY-MM-DD)
date_pattern = re.compile(r'\d{4}-\d{2}-\d{2}')

# Iterate over each line in the file
with open(file_path, "r", encoding="utf-8", errors="ignore") as file:
    for line in file:
        try:
            line = line.strip().encode('utf-8').decode('utf-8')
        except UnicodeDecodeError:
            continue

        # Check if the line contains a date
        if date_pattern.search(line):
            break  # Stop reading lines if a date is found

        # Check if the line contains the catchphrase
        if line.strip() == "+17737937551":
            # Get the content from the next line
            next_line = next(file, '').strip()
            messages.append(next_line)
            phone_numbers.append("+17737937551")

# Create a pandas DataFrame
df = pd.DataFrame({'Phone Number': phone_numbers, 'Message': messages})
print(df)
# Out:
#       Phone Number                                            Message
# 0     +17737937551          Sorry I missed your call. Need something?
# 1     +17737937551                                             Hello?
# 2     +17737937551               Yes, please ask if can move to 11:30
# 3     +17737937551                                          Thank you
# 4     +17737937551                                 Why what happened?
# ...            ...                                                ...
# 4667  +17737937551                                How about the case?
# 4668  +17737937551  Send me the link and I can order using my cc a...
# 4669  +17737937551  Btw, did you get to talk to your physics teach...
# 4670  +17737937551  Btw, makena went to the gym yesterday and got ...
# 4671  +17737937551  There is nothing wrong carrying a small bag or...
#
# [4672 rows x 2 columns]

# %%
import pandas as pd
import re

# Read the contents of the file
file_path = "xd.txt"
phone_numbers = []
messages = []
dates = []  # List to store dates

# Regex pattern to match date in the format "Jun 02, 2022 11:19:21 AM"
date_pattern = re.compile(r'[A-Z][a-z]{2} \d{2}, \d{4} \d{2}:\d{2}:\d{2} [AP]M')

# Iterate over each line in the file
with open(file_path, "r", encoding="utf-8", errors="ignore") as file:
    current_date = None  # Initialize variable to store the current date
    for line in file:
        # No need to encode and decode the line again
        line = line.strip()

        # Check if the line contains a date
        match = date_pattern.search(line)
        if match:
            # Update current_date if a date is found
            current_date = match.group()

        # Check if the line contains the catchphrase
        if line.strip() == "+17737937551":
            # Append the current date to dates list
            dates.append(current_date)
            # Get the content from the next line
            next_line = next(file, '').strip()
            messages.append(next_line)
            phone_numbers.append("+17737937551")

# Create a pandas DataFrame
df = pd.DataFrame({'Date': dates, 'Phone Number': phone_numbers, 'Message': messages})
print(df)
# Out:
#                           Date  Phone Number  \
# 0     Jun 02, 2022 11:19:21 AM  +17737937551
# 1     Jun 02, 2022 11:19:47 AM  +17737937551
# 2     Jun 02, 2022 11:20:01 AM  +17737937551
# 3     Jun 02, 2022 12:11:27 PM  +17737937551
# 4     Jun 02, 2022 12:11:27 PM  +17737937551
# ...                        ...           ...
# 4667  Feb 11, 2024 12:35:11 PM  +17737937551
# 4668  Feb 11, 2024 12:35:11 PM  +17737937551
# 4669  Feb 11, 2024 12:35:11 PM  +17737937551
# 4670  Feb 11, 2024 12:35:11 PM  +17737937551
# 4671  Feb 11, 2024 12:35:11 PM  +17737937551
#
#                                                 Message
# 0             Sorry I missed your call. Need something?
# 1                                                Hello?
# 2                  Yes, please ask if can move to 11:30
# 3                                             Thank you
# 4                                    Why what happened?
# ...                                                 ...
# 4667                                How about the case?
# 4668  Send me the link and I can order using my cc a...
# 4669  Btw, did you get to talk to your physics teach...
# 4670  Btw, makena went to the gym yesterday and got ...
# 4671  There is nothing wrong carrying a small bag or...
#
# [4672 rows x 3 columns]

# %%
import pandas as pd
import re

# Read the contents of the file
file_path = "xd.txt"
phone_numbers = []
messages = []
dates = []  # List to store dates

# Regex pattern to match date in the format "Jun 02, 2022 11:19:21 AM"
date_pattern = re.compile(r'[A-Z][a-z]{2} \d{2}, \d{4} \d{2}:\d{2}:\d{2} [AP]M')

# Iterate over each line in the file
with open(file_path, "r", encoding="utf-8", errors="ignore") as file:
    current_date = None  # Initialize variable to store the current date
    for line in file:
        # No need to encode and decode the line again
        line = line.strip()

        # Check if the line contains a date
        match = date_pattern.search(line)
        if match:
            # Update current_date if a date is found
            current_date = match.group()

        # Check if the line contains the catchphrase
        if line.strip() == "+17737937551":
            # Append the current date to dates list
            dates.append(current_date)
            # Get the content from the next line
            next_line = next(file, '').strip()
            messages.append(next_line)
            phone_numbers.append("+17737937551")

# Create a pandas DataFrame
df = pd.DataFrame({'Date': dates, 'Phone Number': phone_numbers, 'Message': messages})
print(df)

# %%
df
# Out:
#                           Date  Phone Number  \
# 0     Jun 02, 2022 11:19:21 AM  +17737937551
# 1     Jun 02, 2022 11:19:47 AM  +17737937551
# 2     Jun 02, 2022 11:20:01 AM  +17737937551
# 3     Jun 02, 2022 12:11:27 PM  +17737937551
# 4     Jun 02, 2022 12:11:27 PM  +17737937551
# ...                        ...           ...
# 4667  Feb 11, 2024 12:35:11 PM  +17737937551
# 4668  Feb 11, 2024 12:35:11 PM  +17737937551
# 4669  Feb 11, 2024 12:35:11 PM  +17737937551
# 4670  Feb 11, 2024 12:35:11 PM  +17737937551
# 4671  Feb 11, 2024 12:35:11 PM  +17737937551
#
#                                                 Message
# 0             Sorry I missed your call. Need something?
# 1                                                Hello?
# 2                  Yes, please ask if can move to 11:30
# 3                                             Thank you
# 4                                    Why what happened?
# ...                                                 ...
# 4667                                How about the case?
# 4668  Send me the link and I can order using my cc a...
# 4669  Btw, did you get to talk to your physics teach...
# 4670  Btw, makena went to the gym yesterday and got ...
# 4671  There is nothing wrong carrying a small bag or...
#
# [4672 rows x 3 columns]

# %%
import pandas as pd
import re

# Read the contents of the file
file_path = "xd.txt"
phone_numbers = []
messages = []
dates = []  # List to store dates

# Regex pattern to match date in the format "Jun 02, 2022 11:19:21 AM"
date_pattern = re.compile(r'[A-Z][a-z]{2} \d{2}, \d{4} \d{2}:\d{2}:\d{2} [AP]M')

# Iterate over each line in the file
with open(file_path, "r", encoding="utf-8", errors="ignore") as file:
    current_date = None  # Initialize variable to store the current date
    for line in file:
        # No need to encode and decode the line again
        line = line.strip()

        # Check if the line contains a date
        match = date_pattern.search(line)
        if match:
            # Update current_date if a date is found
            current_date = match.group()

        # Check if the line contains the catchphrase
        if line.strip() == "Me":
            # Append the current date to dates list
            dates.append(current_date)
            # Get the content from the next line
            next_line = next(file, '').strip()
            messages.append(next_line)
            phone_numbers.append("Me")

# Create a pandas DataFrame
df = pd.DataFrame({'Date': dates, 'Phone Number': phone_numbers, 'Message': messages})
print(df)
# Out:
#                           Date Phone Number  \
# 0     Jun 02, 2022 11:19:47 AM           Me
# 1     Jun 02, 2022 11:19:59 AM           Me
# 2     Jun 02, 2022 12:11:22 PM           Me
# 3     Jun 02, 2022 12:11:27 PM           Me
# 4     Jun 02, 2022 12:11:27 PM           Me
# ...                        ...          ...
# 3620  Feb 11, 2024 12:35:11 PM           Me
# 3621  Feb 11, 2024 12:35:11 PM           Me
# 3622  Feb 11, 2024 12:35:11 PM           Me
# 3623  Feb 11, 2024 12:35:11 PM           Me
# 3624  Feb 11, 2024 12:35:11 PM           Me
#
#                                                 Message
# 0     do i call the saxophone place and say my dad w...
# 1        and say if that doesn’t work i’ll do next week
# 2                                sorry i missed ur call
# 3                     i will take makena to kaiser soon
# 4     we have to get next week friday at 10 for saxo...
# ...                                                 ...
# 3620                                          2 seconds
# 3621                                             Thanks
# 3622                              happy valentine’s day
# 3623                                         no it’s ok
# 3624                                     oh i will look
#
# [3625 rows x 3 columns]

# %%
import pandas as pd
import re

# Read the contents of the file
file_path = "xd.txt"
phone_numbers = []
messages = []
dates = []  # List to store dates

# Regex pattern to match date in the format "Jun 02, 2022 11:19:21 AM"
date_pattern = re.compile(r'[A-Z][a-z]{2} \d{2}, \d{4} \d{2}:\d{2}:\d{2} [AP]M')

# Iterate over each line in the file
with open(file_path, "r", encoding="utf-8", errors="ignore") as file:
    current_date = None  # Initialize variable to store the current date
    for line in file:
        # No need to encode and decode the line again
        line = line.strip()

        # Check if the line contains a date
        match = date_pattern.search(line)
        if match:
            # Update current_date if a date is found
            current_date = match.group()

        # Check if the line contains the catchphrase
        if line.strip() == "Me":
            # Append the current date to dates list
            dates.append(current_date)
            # Get the content from the next line
            next_line = next(file, '').strip()
            messages.append(next_line)
            phone_numbers.append("Me")

# Create a pandas DataFrame
df = pd.DataFrame({'Date': dates, 'Phone Number': phone_numbers, 'Message': messages})
print(df)

# Read the contents of the file
file_path = "xd.txt"
phone_numbers = []
messages = []
dates = []  # List to store dates

# Regex pattern to match date in the format "Jun 02, 2022 11:19:21 AM"
date_pattern = re.compile(r'[A-Z][a-z]{2} \d{2}, \d{4} \d{2}:\d{2}:\d{2} [AP]M')

# Iterate over each line in the file
with open(file_path, "r", encoding="utf-8", errors="ignore") as file:
    current_date = None  # Initialize variable to store the current date
    for line in file:
        # No need to encode and decode the line again
        line = line.strip()

        # Check if the line contains a date
        match = date_pattern.search(line)
        if match:
            # Update current_date if a date is found
            current_date = match.group()

        # Check if the line contains the catchphrase
        if line.strip() == "+17737937551":
            # Append the current date to dates list
            dates.append(current_date)
            # Get the content from the next line
            next_line = next(file, '').strip()
            messages.append(next_line)
            phone_numbers.append("+17737937551")

# Create a pandas DataFrame
df1 = pd.DataFrame({'Date': dates, 'Phone Number': phone_numbers, 'Message': messages})
print(df1)

import pandas as pd

# Assuming df1 and df2 are your two pandas DataFrames
# Concatenate the two DataFrames
combined_df = pd.concat([df, df1], ignore_index=True)

# Sort the combined DataFrame based on the 'Date' category
combined_df.sort_values(by='Date', inplace=True)

# Reset index after sorting
combined_df.reset_index(drop=True, inplace=True)

# Print the combined and sorted DataFrame
print(combined_df)
# Out:
#                           Date Phone Number  \
# 0     Jun 02, 2022 11:19:47 AM           Me
# 1     Jun 02, 2022 11:19:59 AM           Me
# 2     Jun 02, 2022 12:11:22 PM           Me
# 3     Jun 02, 2022 12:11:27 PM           Me
# 4     Jun 02, 2022 12:11:27 PM           Me
# ...                        ...          ...
# 3620  Feb 11, 2024 12:35:11 PM           Me
# 3621  Feb 11, 2024 12:35:11 PM           Me
# 3622  Feb 11, 2024 12:35:11 PM           Me
# 3623  Feb 11, 2024 12:35:11 PM           Me
# 3624  Feb 11, 2024 12:35:11 PM           Me
#
#                                                 Message
# 0     do i call the saxophone place and say my dad w...
# 1        and say if that doesn’t work i’ll do next week
# 2                                sorry i missed ur call
# 3                     i will take makena to kaiser soon
# 4     we have to get next week friday at 10 for saxo...
# ...                                                 ...
# 3620                                          2 seconds
# 3621                                             Thanks
# 3622                              happy valentine’s day
# 3623                                         no it’s ok
# 3624                                     oh i will look
#
# [3625 rows x 3 columns]
#                           Date  Phone Number  \
# 0     Jun 02, 2022 11:19:21 AM  +17737937551
# 1     Jun 02, 2022 11:19:47 AM  +17737937551
# 2     Jun 02, 2022 11:20:01 AM  +17737937551
# 3     Jun 02, 2022 12:11:27 PM  +17737937551
# 4     Jun 02, 2022 12:11:27 PM  +17737937551
# ...                        ...           ...
# 4667  Feb 11, 2024 12:35:11 PM  +17737937551
# 4668  Feb 11, 2024 12:35:11 PM  +17737937551
# 4669  Feb 11, 2024 12:35:11 PM  +17737937551
# 4670  Feb 11, 2024 12:35:11 PM  +17737937551
# 4671  Feb 11, 2024 12:35:11 PM  +17737937551
#
#                                                 Message
# 0             Sorry I missed your call. Need something?
# 1                                                Hello?
# 2                  Yes, please ask if can move to 11:30
# 3                                             Thank you
# 4                                    Why what happened?
# ...                                                 ...
# 4667                                How about the case?
# 4668  Send me the link and I can order using my cc a...
# 4669  Btw, did you get to talk to your physics teach...
# 4670  Btw, makena went to the gym yesterday and got ...
# 4671  There is nothing wrong carrying a small bag or...
#
# [4672 rows x 3 columns]
#                           Date  Phone Number  \
# 0     Apr 01, 2023 10:12:56 PM  +17737937551
# 1     Apr 01, 2023 10:16:00 PM            Me
# 2     Apr 01, 2023 10:20:23 PM  +17737937551
# 3     Apr 01, 2023 10:20:48 PM  +17737937551
# 4     Apr 01, 2023 10:22:59 PM            Me
# ...                        ...           ...
# 8292  Sep 29, 2023 12:25:47 PM            Me
# 8293  Sep 29, 2023 12:26:06 PM  +17737937551
# 8294  Sep 29, 2023 12:26:17 PM            Me
# 8295  Sep 29, 2023 12:26:17 PM  +17737937551
# 8296  Sep 29, 2023 12:26:17 PM  +17737937551
#
#                                                 Message
# 0                            Hi. Is dinner almost over?
# 1                           no mia just got off of work
# 2     What? Can you be home by 11? You have another ...
# 3                             We are waiting up for you
# 4                           no we aren’t even there yet
# ...                                                 ...
# 8292                                               now?
# 8293                                      Are you free?
# 8294                                                 ya
# 8295                                                  👋
# 8296  Good morning son. Forgot to call you last nigh...
#
# [8297 rows x 3 columns]

# %%
combined_df['Date'] = pd.to_datetime(df['Date'], format='%b %d, %Y %I:%M:%S %p', errors='coerce')

# Check if conversion was successful
if pd.notnull(combined_df['Date']).all():
    # Convert datetime values to concatenated integer in the format YEAR:MONTH:DAY:TIME
    combined_df['Date'] = combined_df['Date'].dt.year * 10**10 + combined_df['Date'].dt.month * 10**8 + combined_df['Date'].dt.day * 10**6 + combined_df['Date'].dt.hour * 10**4 + combined_df['Date'].dt.minute * 10**2 + combined_df['Date'].dt.second
else:
    print("Some values in 'Date' column could not be converted to datetime format.")

print(combined_df)
# Out:
# Some values in 'Date' column could not be converted to datetime format.
#                     Date  Phone Number  \
# 0    2022-06-02 11:19:47  +17737937551
# 1    2022-06-02 11:19:59            Me
# 2    2022-06-02 12:11:22  +17737937551
# 3    2022-06-02 12:11:27  +17737937551
# 4    2022-06-02 12:11:27            Me
# ...                  ...           ...
# 8292                 NaT            Me
# 8293                 NaT  +17737937551
# 8294                 NaT            Me
# 8295                 NaT  +17737937551
# 8296                 NaT  +17737937551
#
#                                                 Message
# 0                            Hi. Is dinner almost over?
# 1                           no mia just got off of work
# 2     What? Can you be home by 11? You have another ...
# 3                             We are waiting up for you
# 4                           no we aren’t even there yet
# ...                                                 ...
# 8292                                               now?
# 8293                                      Are you free?
# 8294                                                 ya
# 8295                                                  👋
# 8296  Good morning son. Forgot to call you last nigh...
#
# [8297 rows x 3 columns]

# %%
combined_df
# Out:
#                     Date  Phone Number  \
# 0    2022-06-02 11:19:47  +17737937551
# 1    2022-06-02 11:19:59            Me
# 2    2022-06-02 12:11:22  +17737937551
# 3    2022-06-02 12:11:27  +17737937551
# 4    2022-06-02 12:11:27            Me
# ...                  ...           ...
# 8292                 NaT            Me
# 8293                 NaT  +17737937551
# 8294                 NaT            Me
# 8295                 NaT  +17737937551
# 8296                 NaT  +17737937551
#
#                                                 Message
# 0                            Hi. Is dinner almost over?
# 1                           no mia just got off of work
# 2     What? Can you be home by 11? You have another ...
# 3                             We are waiting up for you
# 4                           no we aren’t even there yet
# ...                                                 ...
# 8292                                               now?
# 8293                                      Are you free?
# 8294                                                 ya
# 8295                                                  👋
# 8296  Good morning son. Forgot to call you last nigh...
#
# [8297 rows x 3 columns]

# %%
import pandas as pd
import re

# Read the contents of the file
file_path = "xd.txt"
phone_numbers = []
messages = []
dates = []  # List to store dates

# Regex pattern to match date in the format "Jun 02, 2022 11:19:21 AM"
date_pattern = re.compile(r'[A-Z][a-z]{2} \d{2}, \d{4} \d{2}:\d{2}:\d{2} [AP]M')

# Iterate over each line in the file
with open(file_path, "r", encoding="utf-8", errors="ignore") as file:
    current_date = None  # Initialize variable to store the current date
    for line in file:
        # No need to encode and decode the line again
        line = line.strip()

        # Check if the line contains a date
        match = date_pattern.search(line)
        if match:
            # Update current_date if a date is found
            current_date = match.group()

        # Check if the line contains the catchphrase
        if line.strip() == "Me":
            # Append the current date to dates list
            dates.append(current_date)
            # Get the content from the next line
            next_line = next(file, '').strip()
            messages.append(next_line)
            phone_numbers.append("Me")

# Create a pandas DataFrame
df = pd.DataFrame({'Date': dates, 'Phone Number': phone_numbers, 'Message': messages})
print(df)

# Read the contents of the file
file_path = "xd.txt"
phone_numbers = []
messages = []
dates = []  # List to store dates

# Regex pattern to match date in the format "Jun 02, 2022 11:19:21 AM"
date_pattern = re.compile(r'[A-Z][a-z]{2} \d{2}, \d{4} \d{2}:\d{2}:\d{2} [AP]M')

# Iterate over each line in the file
with open(file_path, "r", encoding="utf-8", errors="ignore") as file:
    current_date = None  # Initialize variable to store the current date
    for line in file:
        # No need to encode and decode the line again
        line = line.strip()

        # Check if the line contains a date
        match = date_pattern.search(line)
        if match:
            # Update current_date if a date is found
            current_date = match.group()

        # Check if the line contains the catchphrase
        if line.strip() == "+17737937551":
            # Append the current date to dates list
            dates.append(current_date)
            # Get the content from the next line
            next_line = next(file, '').strip()
            messages.append(next_line)
            phone_numbers.append("+17737937551")

# Create a pandas DataFrame
df1 = pd.DataFrame({'Date': dates, 'Phone Number': phone_numbers, 'Message': messages})
print(df1)

import pandas as pd

# Assuming df1 and df2 are your two pandas DataFrames
# Concatenate the two DataFrames
comb = pd.concat([df, df1], ignore_index=True)

# Sort the combined DataFrame based on the 'Date' category
comb.sort_values(by='Date', inplace=True)

# Reset index after sorting
comb.reset_index(drop=True, inplace=True)

# Print the combined and sorted DataFrame
print(comb)
# Out:
#                           Date Phone Number  \
# 0     Jun 02, 2022 11:19:47 AM           Me
# 1     Jun 02, 2022 11:19:59 AM           Me
# 2     Jun 02, 2022 12:11:22 PM           Me
# 3     Jun 02, 2022 12:11:27 PM           Me
# 4     Jun 02, 2022 12:11:27 PM           Me
# ...                        ...          ...
# 3620  Feb 11, 2024 12:35:11 PM           Me
# 3621  Feb 11, 2024 12:35:11 PM           Me
# 3622  Feb 11, 2024 12:35:11 PM           Me
# 3623  Feb 11, 2024 12:35:11 PM           Me
# 3624  Feb 11, 2024 12:35:11 PM           Me
#
#                                                 Message
# 0     do i call the saxophone place and say my dad w...
# 1        and say if that doesn’t work i’ll do next week
# 2                                sorry i missed ur call
# 3                     i will take makena to kaiser soon
# 4     we have to get next week friday at 10 for saxo...
# ...                                                 ...
# 3620                                          2 seconds
# 3621                                             Thanks
# 3622                              happy valentine’s day
# 3623                                         no it’s ok
# 3624                                     oh i will look
#
# [3625 rows x 3 columns]
#                           Date  Phone Number  \
# 0     Jun 02, 2022 11:19:21 AM  +17737937551
# 1     Jun 02, 2022 11:19:47 AM  +17737937551
# 2     Jun 02, 2022 11:20:01 AM  +17737937551
# 3     Jun 02, 2022 12:11:27 PM  +17737937551
# 4     Jun 02, 2022 12:11:27 PM  +17737937551
# ...                        ...           ...
# 4667  Feb 11, 2024 12:35:11 PM  +17737937551
# 4668  Feb 11, 2024 12:35:11 PM  +17737937551
# 4669  Feb 11, 2024 12:35:11 PM  +17737937551
# 4670  Feb 11, 2024 12:35:11 PM  +17737937551
# 4671  Feb 11, 2024 12:35:11 PM  +17737937551
#
#                                                 Message
# 0             Sorry I missed your call. Need something?
# 1                                                Hello?
# 2                  Yes, please ask if can move to 11:30
# 3                                             Thank you
# 4                                    Why what happened?
# ...                                                 ...
# 4667                                How about the case?
# 4668  Send me the link and I can order using my cc a...
# 4669  Btw, did you get to talk to your physics teach...
# 4670  Btw, makena went to the gym yesterday and got ...
# 4671  There is nothing wrong carrying a small bag or...
#
# [4672 rows x 3 columns]
#                           Date  Phone Number  \
# 0     Apr 01, 2023 10:12:56 PM  +17737937551
# 1     Apr 01, 2023 10:16:00 PM            Me
# 2     Apr 01, 2023 10:20:23 PM  +17737937551
# 3     Apr 01, 2023 10:20:48 PM  +17737937551
# 4     Apr 01, 2023 10:22:59 PM            Me
# ...                        ...           ...
# 8292  Sep 29, 2023 12:25:47 PM            Me
# 8293  Sep 29, 2023 12:26:06 PM  +17737937551
# 8294  Sep 29, 2023 12:26:17 PM            Me
# 8295  Sep 29, 2023 12:26:17 PM  +17737937551
# 8296  Sep 29, 2023 12:26:17 PM  +17737937551
#
#                                                 Message
# 0                            Hi. Is dinner almost over?
# 1                           no mia just got off of work
# 2     What? Can you be home by 11? You have another ...
# 3                             We are waiting up for you
# 4                           no we aren’t even there yet
# ...                                                 ...
# 8292                                               now?
# 8293                                      Are you free?
# 8294                                                 ya
# 8295                                                  👋
# 8296  Good morning son. Forgot to call you last nigh...
#
# [8297 rows x 3 columns]

# %%
comb
# Out:
#                           Date  Phone Number  \
# 0     Apr 01, 2023 10:12:56 PM  +17737937551
# 1     Apr 01, 2023 10:16:00 PM            Me
# 2     Apr 01, 2023 10:20:23 PM  +17737937551
# 3     Apr 01, 2023 10:20:48 PM  +17737937551
# 4     Apr 01, 2023 10:22:59 PM            Me
# ...                        ...           ...
# 8292  Sep 29, 2023 12:25:47 PM            Me
# 8293  Sep 29, 2023 12:26:06 PM  +17737937551
# 8294  Sep 29, 2023 12:26:17 PM            Me
# 8295  Sep 29, 2023 12:26:17 PM  +17737937551
# 8296  Sep 29, 2023 12:26:17 PM  +17737937551
#
#                                                 Message
# 0                            Hi. Is dinner almost over?
# 1                           no mia just got off of work
# 2     What? Can you be home by 11? You have another ...
# 3                             We are waiting up for you
# 4                           no we aren’t even there yet
# ...                                                 ...
# 8292                                               now?
# 8293                                      Are you free?
# 8294                                                 ya
# 8295                                                  👋
# 8296  Good morning son. Forgot to call you last nigh...
#
# [8297 rows x 3 columns]

# %%
comb['Date'] = pd.to_datetime(comb['Date'], format='%b %d, %Y %I:%M:%S %p')

# Convert datetime values to concatenated integer without seconds and first two digits of the year
comb['Date'] = comb['Date'].dt.strftime('%y%m%d%H%M').astype(float)

print(comb)
# Out:
#               Date  Phone Number  \
# 0     2.304012e+09  +17737937551
# 1     2.304012e+09            Me
# 2     2.304012e+09  +17737937551
# 3     2.304012e+09  +17737937551
# 4     2.304012e+09            Me
# ...            ...           ...
# 8292  2.309291e+09            Me
# 8293  2.309291e+09  +17737937551
# 8294  2.309291e+09            Me
# 8295  2.309291e+09  +17737937551
# 8296  2.309291e+09  +17737937551
#
#                                                 Message
# 0                            Hi. Is dinner almost over?
# 1                           no mia just got off of work
# 2     What? Can you be home by 11? You have another ...
# 3                             We are waiting up for you
# 4                           no we aren’t even there yet
# ...                                                 ...
# 8292                                               now?
# 8293                                      Are you free?
# 8294                                                 ya
# 8295                                                  👋
# 8296  Good morning son. Forgot to call you last nigh...
#
# [8297 rows x 3 columns]

# %%
comb
# Out:
#               Date  Phone Number  \
# 0     2.304012e+09  +17737937551
# 1     2.304012e+09            Me
# 2     2.304012e+09  +17737937551
# 3     2.304012e+09  +17737937551
# 4     2.304012e+09            Me
# ...            ...           ...
# 8292  2.309291e+09            Me
# 8293  2.309291e+09  +17737937551
# 8294  2.309291e+09            Me
# 8295  2.309291e+09  +17737937551
# 8296  2.309291e+09  +17737937551
#
#                                                 Message
# 0                            Hi. Is dinner almost over?
# 1                           no mia just got off of work
# 2     What? Can you be home by 11? You have another ...
# 3                             We are waiting up for you
# 4                           no we aren’t even there yet
# ...                                                 ...
# 8292                                               now?
# 8293                                      Are you free?
# 8294                                                 ya
# 8295                                                  👋
# 8296  Good morning son. Forgot to call you last nigh...
#
# [8297 rows x 3 columns]

# %%
import pandas as pd
import re

# Read the contents of the file
file_path = "xd.txt"
phone_numbers = []
messages = []
dates = []  # List to store dates
number = "+17737937551"

# Regex pattern to match date in the format "Jun 02, 2022 11:19:21 AM"
date_pattern = re.compile(r'[A-Z][a-z]{2} \d{2}, \d{4} \d{2}:\d{2}:\d{2} [AP]M')

# Iterate over each line in the file
with open(file_path, "r", encoding="utf-8", errors="ignore") as file:
    current_date = None  # Initialize variable to store the current date
    for line in file:
        # No need to encode and decode the line again
        line = line.strip()

        # Check if the line contains a date
        match = date_pattern.search(line)
        if match:
            # Update current_date if a date is found
            current_date = match.group()

        # Check if the line contains the catchphrase
        if line.strip() == "Me":
            # Append the current date to dates list
            dates.append(current_date)
            # Get the content from the next line
            next_line = next(file, '').strip()
            messages.append(next_line)
            phone_numbers.append(False)

# Create a pandas DataFrame
df = pd.DataFrame({'Date': dates, 'Phone Number': phone_numbers, 'Message': messages})

phone_numbers = []
messages = []
dates = []  # List to store dates

# Regex pattern to match date in the format "Jun 02, 2022 11:19:21 AM"
date_pattern = re.compile(r'[A-Z][a-z]{2} \d{2}, \d{4} \d{2}:\d{2}:\d{2} [AP]M')

# Iterate over each line in the file
with open(file_path, "r", encoding="utf-8", errors="ignore") as file:
    current_date = None  # Initialize variable to store the current date
    for line in file:
        # No need to encode and decode the line again
        line = line.strip()

        # Check if the line contains a date
        match = date_pattern.search(line)
        if match:
            # Update current_date if a date is found
            current_date = match.group()

        # Check if the line contains the catchphrase
        if line.strip() == number:
            # Append the current date to dates list
            dates.append(current_date)
            # Get the content from the next line
            next_line = next(file, '').strip()
            messages.append(next_line)
            phone_numbers.append(True)

# Create a pandas DataFrame
df1 = pd.DataFrame({'Date': dates, 'Phone Number': phone_numbers, 'Message': messages})

# Assuming df1 and df2 are your two pandas DataFrames
# Concatenate the two DataFrames
comb = pd.concat([df, df1], ignore_index=True)

comb['Date'] = pd.to_datetime(comb['Date'], format='%b %d, %Y %I:%M:%S %p')

# Convert datetime values to concatenated integer without seconds and first two digits of the year
comb['Date'] = comb['Date'].dt.strftime('%y%m%d%H%M').astype(float)

# Sort the combined DataFrame based on the 'Date' category
comb.sort_values(by='Date', inplace=True)

# Reset index after sorting
comb.reset_index(drop=True, inplace=True)

comb['Order'] = range(1, len(comb) + 1)

# Print the combined and sorted DataFrame
comb.to_csv("file_name.csv")

# %%
comb.to_csv("xd2.csv")

# %%
comb
# Out:
#               Date  Phone Number  \
# 0     2.206021e+09         False
# 1     2.206021e+09          True
# 2     2.206021e+09          True
# 3     2.206021e+09         False
# 4     2.206021e+09          True
# ...            ...           ...
# 8292  2.402111e+09         False
# 8293  2.402111e+09         False
# 8294  2.402111e+09         False
# 8295  2.402111e+09          True
# 8296  2.402111e+09          True
#
#                                                 Message  Order
# 0     do i call the saxophone place and say my dad w...      1
# 1                                                Hello?      2
# 2             Sorry I missed your call. Need something?      3
# 3        and say if that doesn’t work i’ll do next week      4
# 4                  Yes, please ask if can move to 11:30      5
# ...                                                 ...    ...
# 8292                                             Thanks   8293
# 8293                              happy valentine’s day   8294
# 8294                                         no it’s ok   8295
# 8295                 Anker Nano Portable Charger for...   8296
# 8296  There is nothing wrong carrying a small bag or...   8297
#
# [8297 rows x 4 columns]

# %%
def processCsv(f_path, numb, output_path):
    import pandas as pd
    import re

    # Read the contents of the file
    file_path = f_path
    phone_numbers = []
    messages = []
    dates = []  # List to store dates
    number = numb

    # Regex pattern to match date in the format "Jun 02, 2022 11:19:21 AM"
    date_pattern = re.compile(r'[A-Z][a-z]{2} \d{2}, \d{4} \d{2}:\d{2}:\d{2} [AP]M')

    # Iterate over each line in the file
    with open(file_path, "r", encoding="utf-8", errors="ignore") as file:
        current_date = None  # Initialize variable to store the current date
        for line in file:
            # No need to encode and decode the line again
            line = line.strip()

            # Check if the line contains a date
            match = date_pattern.search(line)
            if match:
                # Update current_date if a date is found
                current_date = match.group()

            # Check if the line contains the catchphrase
            if line.strip() == "Me":
                # Append the current date to dates list
                dates.append(current_date)
                # Get the content from the next line
                next_line = next(file, '').strip()
                messages.append(next_line)
                phone_numbers.append(False)

    # Create a pandas DataFrame
    df = pd.DataFrame({'Date': dates, 'Phone Number': phone_numbers, 'Message': messages})

    phone_numbers = []
    messages = []
    dates = []  # List to store dates

    # Regex pattern to match date in the format "Jun 02, 2022 11:19:21 AM"
    date_pattern = re.compile(r'[A-Z][a-z]{2} \d{2}, \d{4} \d{2}:\d{2}:\d{2} [AP]M')

    # Iterate over each line in the file
    with open(file_path, "r", encoding="utf-8", errors="ignore") as file:
        current_date = None  # Initialize variable to store the current date
        for line in file:
            # No need to encode and decode the line again
            line = line.strip()

            # Check if the line contains a date
            match = date_pattern.search(line)
            if match:
                # Update current_date if a date is found
                current_date = match.group()

            # Check if the line contains the catchphrase
            if line.strip() == number:
                # Append the current date to dates list
                dates.append(current_date)
                # Get the content from the next line
                next_line = next(file, '').strip()
                messages.append(next_line)
                phone_numbers.append(True)

    # Create a pandas DataFrame
    df1 = pd.DataFrame({'Date': dates, 'Phone Number': phone_numbers, 'Message': messages})

    # Assuming df1 and df2 are your two pandas DataFrames
    # Concatenate the two DataFrames
    comb = pd.concat([df, df1], ignore_index=True)

    comb['Date'] = pd.to_datetime(comb['Date'], format='%b %d, %Y %I:%M:%S %p')

    # Convert datetime values to concatenated integer without seconds and first two digits of the year
    comb['Date'] = comb['Date'].dt.strftime('%y%m%d%H%M').astype(float)

    # Sort the combined DataFrame based on the 'Date' category
    comb.sort_values(by='Date', inplace=True)

    # Reset index after sorting
    comb.reset_index(drop=True, inplace=True)

    comb['Order'] = range(1, len(comb) + 1)

    # Print the combined and sorted DataFrame
    comb.to_csv(output_path)
    
file_path = "xd.txt"
number = "+17737937551"
output_path = "output_file.csv"
processCsv(file_path, number, output_path)
